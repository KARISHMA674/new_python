# %% [markdown]
# <a href="https://colab.research.google.com/github/KARISHMA674/new_python/blob/main/exception_handling_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# using try/exception block

# %%
print("practicing for try block")
try:
    numerator=50
    denom=int(input("enter the denominator: "))
    quotient=(numerator/denom)
    print(quotient)
    print("divison performes successfullly")
except ZeroDivisionError:
    print("denominator as zero----not allowed---")
print("outside try-----except block-----")
# Out:
# practicing for try block
# enter the denominator: 5
# 10.0
# divison performes successfullly
# outside try-----except block-----

# %%
print("handling multiple exception")
try:
    numerator=50
    denom=int(input("enter the denominator: "))
    print(numerator/denom)
    print("divison performes successfullly")
except ZeroDivisionError:
    print("denominator as zero----not allowed---")
except ValueError:
    print("only integers should be entered")
# Out:
# handling multiple exception
# enter the denominator: 0
# denominator as zero----not allowed---

# %%
print("handling multiple exception")
try:
    numerator=50
    denom=int(input("enter the denominator: "))
    print(numerator/denom)
    print("divison performes successfullly")
except ValueError:
    print("only integers should be entered")
except :
    print("oops---some exception raised----")
# Out:
# handling multiple exception
# enter the denominator: 10
# 5.0
# divison performes successfullly

# %% [markdown]
# using try with else

# %%
print("handling  exception using try----except----else")
try:
    numerator=50
    denom=int(input("enter the denominator: "))
    quotient=(numerator/denom)
    print("divison performes successfullly")
except ZeroDivisionError:
    print("denominator as zero----not allowed---")
except ValueError:
    print("only integers should be entered")
else:
    print("The result of divison operation is",quotient)
# Out:
# handling  exception using try----except----else
# enter the denominator: 10
# divison performes successfullly
# The result of divison operation is 5.0

# %% [markdown]
# using try with else  and finally

# %%
print("handling  exception using try----except----else----finally")
try:
    numerator=50
    denom=int(input("enter the denominator: "))
    quotient=(numerator/denom)
    print("divison performes successfullly")
except ZeroDivisionError:
    print("denominator as zero----not allowed---")
except ValueError:
    print("only integers should be entered")
else:
    print("The result of divison operation is",quotient)
finally:
    print("over and out")
# Out:
# handling  exception using try----except----else----finally
# enter the denominator: 5
# divison performes successfullly
# The result of divison operation is 10.0
# over and out

# %% [markdown]
# file name
# <r>=open the file in read only.
# <rb>=open the file in binary and read only mode.
# <r+>or<+r>=opens the fie in both read and write mode.<w>=open the file in write mode if the file already exsits all the contents will be over write mode
# <wb+>or<+wb>=opnes the file in read,write and binary mode.
#
# <a>= opens the file in append if the file does not exsits then end of the file a new file will be
# created
#
# <a+>w<+a>=open the file in append and read mode .if the file does not exsits of the file exsits then
# it will be creuted new file.
# write()= writing a single string for writing a squence of strings.
# with open(file_name,access_mode)as file_object:
#    closed outomaticuly
# with open('myfile.text','r+')as myobject:
#  content=myobject.read()

# %%
with open("yourfile.text","w")as f:
    f.write("hello python")
with open("yourfile.text","r+")as myobject:
    content=myobject.read()
    print(content)
myobject_file=open("name.text","w")
myobject_file.write("hey i have started using file in python \n")
myobject_file.close()
# Out:
# hello python

# %% [markdown]
# lamda function

# %%
def apply(criteria,n):
  count=0
  for i in range(n+1):
    if criteria(i):
      count+=1
  return count
def is_even(x):
    return x%2==0
print(apply(is_even,10))
# Out:
# 6

# %%
def apply(criteria,n):
    count=0
    for i in range(n+1):
        if criteria(i):
            count+=1
    return count
def is_even(x):
    return x%3==0
print(apply(is_even,10))
# Out:
# 4

# %%
#anonymous function
'''def is_even(x):
    returnx%2=0
lambda x:x%2==0'''

def do_twice(n,fn):
    return fn(fn(n))
print(do_twice (3,lambda x:x**2))
# Out:
# 81

# %%
#single argument
add_ten=lambda x:x+20
print(add_ten(5))
# Out:
# 25

# %%
#multiple argument
multiply=lambda a,b:a*b
print (multiply(5,6))
# Out:
# 30

# %%
#using with map()
number=[1,2,3,4]
doubled=list(map(lambda x:x*2,number))
print(doubled)
# Out:
# [2, 4, 6, 8]

# %%
#ussing with filter
number=[1,2,3,4,5,6]
evens=list[filter(lambda x:x%5==0,number)]
print(evens)
# Out:
# list[<filter object at 0x788645af7400>]

# %%
#sorted and sort
pairs=[('alice',25),('bob',19),('charlie',30)]
sorted_pairs=sorted(pairs,key= lambda person:person[1])

print(sorted_pairs)
# Out:
# [('bob', 19), ('alice', 25), ('charlie', 30)]

# %%
#sorted and sort
pairs=[('alice',25),('bob',19),('charlie',30)]
sorted_pairs=sorted(pairs,key= lambda person:person[1])

print(sorted_pairs)
# Out:
# [('bob', 19), ('alice', 25), ('charlie', 30)]

# %%
from functools import reduce
numbers=[1,2,3,4,5]
total_sum=reduce(lambda x,y:x+y,number)
print("addition:",total_sum)

total_sub = reduce(lambda x, y: x - y, numbers)
print("Subtraction:", total_sub)

total_multiply = reduce(lambda x, y: x * y, numbers)
print("Multiplication:", total_multiply)

total_div = reduce(lambda x, y: x / y, numbers)
print("Division:", total_div)
# Out:
# addition 21
# Subtraction: -13
# Multiplication: 120
# Division: 0.008333333333333333

# %%
from functools import reduce
total_sum=lambda x,y,z,k,m:x+y+z+k+m
num=(total_sum(1,2,3,4,5))
print("sum:",num)
# Out:
# sum: 15
