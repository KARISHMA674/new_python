# %% [markdown]
# <a href="https://colab.research.google.com/github/KARISHMA674/new_python/blob/main/python_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **python function**

# %%
a=int(input("enter a Ist no: "))
b=int(input("enter a IInd no: "))
c=int(a)+int(b)
print(c)
d=int(a)-int(b)
print(d)
e=int(a)*int(b)
print(e)
f=int(a)/int(b)
print(f)
# Out:
# enter a Ist no: 5
# enter a IInd no: 6
# 11
# -1
# 30
# 0.8333333333333334

# %%
def addnum():
    a=int(input("enter a Ist no: "))
    b=int(input("enter a IInd no: "))
    c=int(a)+int(b)
    print(c)
print(addnum())
# Out:
# enter a Ist no: 4
# enter a IInd no: 5
# 9
# None

# %%
def subnum():
    a=int(input("enter a Ist no: "))
    b=int(input("enter a IInd no: "))
    d=int(a)-int(b)
    print(d)
print(subnum())
# Out:
# enter a Ist no: 4
# enter a IInd no: 2
# 2
# None

# %%
def multnum():
    a=int(input("enter a Ist no: "))
    b=int(input("enter a IInd no: "))
    e=int(a)*int(b)
    print(e)
print(multnum())
# Out:
# enter a Ist no: 3
# enter a IInd no: 4
# 12
# None

# %%
def divnum():
    a=int(input("enter a Ist no: "))
    b=int(input("enter a IInd no: "))
    f=int(a)/int(b)
    print(f)
print(divnum())
# Out:
# enter a Ist no: 4
# enter a IInd no: 2
# 2.0
# None

# %% [markdown]
# WAP using a user defined function that accepts the first name and last name as arguments,concatinate them as full name and display.

# %%
def fullname(first,last):
    fullname=first+" "+last
    print("hello !",fullname)
first=input("enter a first name: ")
last=input("enter a last name: ")
fullname(first,last)
# Out:
# enter a first name: Ranjit
# enter a last name: Gupta
# hello ! Ranjit Gupta

# %% [markdown]
# WAP using user defined function that accepts length and breadth of the rectangle and return the area and perimeter of the rectangle.

# %%
def Area_Perimeter(length,breadth):
    area=length*breadth
    perimeter=2*(length+breadth)
    return(area,perimeter)
length=int(input("Enter length of the rectangle: "))
breadth=int(input("Enter the breadth of the rectangle: "))
area,perimeter=Area_Perimeter(length,breadth)
print(f"Area of the rectangle: {area} ")
print(f"Perimeter of the rectangle : {perimeter}")
# Out:
# Enter length of the rectangle: 2
# Enter the breadth of the rectangle: 2
# Area of the rectangle: 4
# Perimeter of the rectangle : 8

# %%
def welcome():
    print("welcome India.....");
    print("Hello World");
    a=5;
    b=6;
    c=a+b;
    print(c)
    list=["mango","apple","orange"];
    print(list)
    dict={'mohan':24,'sohan':76,'rohan':90}
    print(dict)
    tup=(2,3,4,5)
    print(tup)
welcome()
# Out:
# welcome India.....
# Hello World
# 11
# ['mango', 'apple', 'orange']
# {'mohan': 24, 'sohan': 76, 'rohan': 90}
# (2, 3, 4, 5)

# %% [markdown]
# **factorial program**

# %%
def calcfact(num):
  fact=1
  for i in range(num,0,-1):
    fact=fact*i
  print("factorial of",num,"is",fact)
num=int(input("enter the number: "))
calcfact(num)
# Out:
# enter the number: 6
# factorial of 6 is 720

# %% [markdown]
# **Tables**

# %%
#WAp number enter by user and print its table.
def table(num):
    for i in range(1,11):
        print(num,"x",i,"=",num*i)
n=int(input("enter any number: "))
table(n)
# Out:
# enter any number: 34
# 34 x 1 = 34
# 34 x 2 = 68
# 34 x 3 = 102
# 34 x 4 = 136
# 34 x 5 = 170
# 34 x 6 = 204
# 34 x 7 = 238
# 34 x 8 = 272
# 34 x 9 = 306
# 34 x 10 = 340

# %%
#table of 25
def tablesof(number):
    for i in range(0,11):
        print(number,"*",i,"is to:",number*i)
n=25;
tablesof(n)
# Out:
# 25 * 0 is to: 0
# 25 * 1 is to: 25
# 25 * 2 is to: 50
# 25 * 3 is to: 75
# 25 * 4 is to: 100
# 25 * 5 is to: 125
# 25 * 6 is to: 150
# 25 * 7 is to: 175
# 25 * 8 is to: 200
# 25 * 9 is to: 225
# 25 * 10 is to: 250

# %%
#table of 59
def tablesof(mynum):
    for a in range(1,21):
        print(mynum,"multiply",a,":",mynum*a)
n=59;
tablesof(n)
# Out:
# 59 multiply 1 : 59
# 59 multiply 2 : 118
# 59 multiply 3 : 177
# 59 multiply 4 : 236
# 59 multiply 5 : 295
# 59 multiply 6 : 354
# 59 multiply 7 : 413
# 59 multiply 8 : 472
# 59 multiply 9 : 531
# 59 multiply 10 : 590
# 59 multiply 11 : 649
# 59 multiply 12 : 708
# 59 multiply 13 : 767
# 59 multiply 14 : 826
# 59 multiply 15 : 885
# 59 multiply 16 : 944
# 59 multiply 17 : 1003
# 59 multiply 18 : 1062
# 59 multiply 19 : 1121
# 59 multiply 20 : 1180

# %%
#average of number.
def average(num1,num2,num3,num4):
    avg=(num1+num2+num3+num4)/4
    print("Average value= ",avg)
n1=int(input("Enter num1: "))
n2=int(input("Enter a num2: "))
n3=int(input("Enter num3: "))
n4=int(input("Enter num4: "))
average(n1,n2,n3,n4)
# Out:
# Enter num1: 2
# Enter a num2: 5
# Enter num3: 75
# Enter num4: 8
# Average value=  22.5

# %%
#function with return
def cube(num):
    return num*num*num
p1=int(input("Enter any number: "))
c=cube(p1)
print(c)
# Out:
# Enter any number: 4
# 64

# %%
#WAP using a user defined functions my mean() to calculate the mean of floating value stores in a list.
def mymean(mylist):
    total=0
    count=0
    for i in mylist:
        total=total+i
        count=count+1
    mean=total/count;
    print("calculate mean is: ",mean);
mylist=[1,2,3,4,5]
mymean(mylist)
# Out:
# calculate mean is:  3.0

# %%
#2.similar type program.
def mymeanfun(programmerlist):
    sum_of_value=0
    no_of_value=0
    for i in programmerlist:
        sum_of_value=sum_of_value+i
        no_of_value=no_of_value+1
    average=sum_of_value/no_of_value
    print("The average of the all values which is give by the programmer in the end of the program: ",average);
programmerlist=[90,36,57,68,45,89,37,24,56,32,55,45]
mymeanfun(programmerlist)
# Out:
# The average of the all values which is give by the programmer in the end of the program:  52.833333333333336

# %%
##WAP using a user defined functions my mean() to calculate the mean of floating value and values enter by the user.

def mymeanfun(programmerlist):
    sum_of_value=0
    no_of_value=0
    for i in programmerlist:
        sum_of_value=sum_of_value+i
        no_of_value=no_of_value+1
    average=sum_of_value/no_of_value
    print("The average of the all values which is give by the programmer in the end of the program: ",average),
I=int(input("enter 1 value: "));
II=int(input("enetr 2 value: "));
III=int(input("enter 3 value: "));
IV=int(input("enetr 4 value: "));
V=int(input("enetr 5 value: "));

programmerlist=[I,II,III,IV,V]
mymeanfun(programmerlist)
# Out:
# enter 1 value: 1
# enetr 2 value: 2
# enter 3 value: 3
# enetr 4 value: 4
# enetr 5 value: 5
# The average of the all values which is give by the programmer in the end of the program:  3.0

# %%
#WAP using a user defined functions my mean() to calculate the mean of floating value and values enter by the user,,#if we want first no average ,the add of previous two no average, then add the previous 3 no average and so on ... #

def mymeanfun(programmerlist):
    sum_of_value=0
    no_of_value=0
    for i in programmerlist:
        sum_of_value=sum_of_value+i
        no_of_value=no_of_value+1
        average=sum_of_value/no_of_value
        print("The average of the all values which is give by the programmer in the end of the program: ",average),
I=int(input("enter 1 value: "));
II=int(input("enetr 2 value: "));
III=int(input("enter 3 value: "));
IV=int(input("enetr 4 value: "));
V=int(input("enetr 5 value: "));

programmerlist=[I,II,III,IV,V]
print(programmerlist)
mymeanfun(programmerlist)
# Out:
# enter 1 value: 1
# enetr 2 value: 2
# enter 3 value: 3
# enetr 4 value: 4
# enetr 5 value: 5
# [1, 2, 3, 4, 5]
# The average of the all values which is give by the programmer in the end of the program:  1.0
# The average of the all values which is give by the programmer in the end of the program:  1.5
# The average of the all values which is give by the programmer in the end of the program:  2.0
# The average of the all values which is give by the programmer in the end of the program:  2.5
# The average of the all values which is give by the programmer in the end of the program:  3.0

# %%
# Area of rectangel
def area_of_rectangle(length,breadth):
  area=length*breadth
  perimeter=2*(length+breadth)
  return(area,perimeter)
length=int(input("Enter the length: "))
breadth=int(input("Enter the breadth: "))

area,perimeter=area_of_rectangle(length,breadth)
print(area)
print(perimeter)
# Out:
# Enter the length: 4
# Enter the breadth: 4
# 16
# 16

# %% [markdown]
# **function with return.**

# %%
#1.method
def cube(num):
  return num*num*num
n1=int(input("enter number: "))
c=cube(n1)
print("cube of number is: ",c)
# Out:
# enter number: 2
# cube of number is:  8

# %%
#2. method
def cube(num):
  return num*num*num
n1=int(input("enter number: "))
print("cube of number is: ",cube(n1))
# Out:
# enter number: 2
# cube of number is:  8

# %%
#3. method
def cube(num):
  return num*num*num
n1=int(input("enter number: "))
val=n1+cube(n1)
print("number+cube=",val)
# Out:
# enter number: 2
# number+cube= 10

# %%
#4. method
def cube(num):
  c=num*num*num
  return c
ni=int(input("enter any number: "))
val=cube(n1)
print("cube=",val)
# Out:
# enter any number: 2
# cube= 8

# %%
import math
def area(r):
  a=math.pi*r*r
  return a
n=int(input("enter radius: "))
ar=area(n)
print("area of the circle: ",ar)
# Out:
# enter radius: 2
# area of the circle:  12.566370614359172

# %%
def max(x,y):
  if x >y:
    return x
  else:
    return y
print("i am not ready");
# Out:
# i am not ready

# %% [markdown]
# **function not returning values**

# %%
def welcome():
    print("welcome to the function");
welcome()
print(welcome())
# Out:
# welcome to the function
# welcome to the function
# None

# %%
def welcome():
    return("welcome to the function");
welcome()
print(welcome())
# Out:
# welcome to the function

# %% [markdown]
# arguments:-(4)
# 1. positional
# 2. Default
# 3. keyword
# 4. variable

# %%
#1.positional argument.
def divide(a,b):
  c=a/b
  print(c)
x=int(input("enter x: "))
y=int(input("enter y: "))
divide(x,y)
# Out:
# enter x: 4
# enter y: 2
# 2.0

# %%
#2. default argument
#def interest(principle,rate,time=13)
#def interest(principle,rate=8.5,time=13)
#def interest(principle,rate=8.5,time) #invalid always give error
def convertbinoct(num,base=2):
  str1=" "
  while num !=0:
    str1 =str1+str(num%base)
    num=num//base
  str1=str1[::-1]
  print(str1)
num=int(input("enter rhe number: "))
convertbinoct(num)
convertbinoct(num,8)
# Out:
# enter rhe number: 6
# 110
# 6

# %%
#3. keyword argument
def drawline(symb,times=30):
    for i in range(times):
      print(symb,end=' ')
    print()
drawline('$',40)
drawline('@')
drawline(times=10,symb='x')
drawline('#',times=20)
# Out:
# $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $ $
# @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @ @
# x x x x x x x x x x
# # # # # # # # # # # # # # # # # # # # #

# %%
#4. variable  arguments
def sum_numbers(*args):
    return sum(args)

print(sum_numbers(5, 10))
print(sum_numbers(1, 2, 3, 4))
# Out:
# 15
# 10

# %%
def main():
  mid = average(10.6,7.2)
  print(mid)
main(average)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3015/2869935618.py in <cell line: 0>()
#       2   mid = average(10.6,7.2)
#       3   print(mid)
# ----> 4 main(average)
#       5
#
# NameError: name 'average' is not defined

# %%
list2=[2,3,4,5,6,7,8,9]
print(list2)
print(list2[1+4])
print(list2[4-1])
print(list2[2*2])
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9]
# 7
# 5
# 6
